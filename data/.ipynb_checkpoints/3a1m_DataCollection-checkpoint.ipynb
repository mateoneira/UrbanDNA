# %%
import requests
from collections import OrderedDict
import logging as lg
import pandas as pd

# %% [markdown]
# Template to request place information from nominatim API for OSM

# %%
url_template = 'https://nominatim.openstreetmap.org/search?format=json&limit=1&q={}'

# %% [markdown]
# Build a query to make request

# %%
query = 'London, Greater London, England, United Kingdom'

# %%
url = url_template.format(query)

# %% [markdown]
# Make a request and save JSON

# %%
response = requests.get(url, timeout=60)
results = response.json()
results
# Out:
# [{'boundingbox': ['51.2867602', '51.6918741', '-0.510375', '0.3340155'],
#   'class': 'place',
#   'display_name': 'London, Greater London, England, UK',
#   'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_place_city.p.20.png',
#   'importance': 1.2954895765402,
#   'lat': '51.5073219',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-0.1276473',
#   'osm_id': '65606',
#   'osm_type': 'relation',
#   'place_id': '207215760',
#   'type': 'city'}]

# %% [markdown]
# Get lat and lon from the results

# %%
if len(results) > 0 and 'lat' in results[0] and 'lon' in results[0]:
    lat= float(results[0]['lat'])
    lon=float(results[0]['lon'])
    point= (lat, lon)
    print('Geocoded "{}" to {}'.format(query, point))
else:
    raise Exception('Nominatim geocoder returned no results for query "{}"'.format(query))
# Out:
# Geocoded "London, Greater London, England, United Kingdom" to (51.5073219, -0.1276473)

# %%
#get bounding box 
bbox_south, bbox_north, bbox_west, bbox_east = [float(x) for x in results[0]['boundingbox']]
bbox_south, bbox_west,bbox_north, bbox_east
# Out:
# (51.2867602, -0.510375, 51.6918741, 0.3340155)

# %% [markdown]
# Connecto to Overpass API

# %%
#send a request to the Overpass API via HTTP POST 
#and return the JSON response. 

#set HTTP url call
url_template='http://overpass-api.de/api/interpreter?data={};{};out;'
output = '[out:json]'

#this query is built by especifying a node and a bounding box
bbox="({},{},{},{})"
bbox=bbox.format(bbox_south, bbox_west,bbox_north, bbox_east)
query = 'node["amenity"="restaurant"]{}'
query = query.format(bbox)
url = url_template.format(output, query)

#make request
response = requests.get(url, timeout=60)
restaurants = response.json()
Erestaurants
# Out:
# {'elements': [{'id': 451153,
#    'lat': 51.6020306,
#    'lon': -0.1935029,
#    'tags': {'amenity': 'restaurant', 'name': 'Central Restaurant'},
#    'type': 'node'},
#   {'id': 20576312,
#    'lat': 51.3095294,
#    'lon': -0.0539522,
#    'tags': {'amenity': 'restaurant', 'name': 'White Lion'},
#    'type': 'node'},
#   {'id': 26544484,
#    'lat': 51.3980144,
#    'lon': -0.1722345,
#    'tags': {'addr:housename': 'The Crown Inn',
#     'addr:housenumber': '407',
#     'addr:postcode': 'CR4 4BG',
#     'addr:street': 'London Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'fhrs:id': '200005',
#     'name': 'Casuarina Tree',
#     'old_name': 'The Crown Inn',
#     'toilets': 'yes',
#     'toilets:access': 'customers'},
#    'type': 'node'},
#   {'id': 27350104,
#    'lat': 51.6435927,
#    'lon': -0.0295238,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Navigation Inn',
#     'operator': 'Harvester'},
#    'type': 'node'},
#   {'id': 27390454,
#    'lat': 51.3894939,
#    'lon': -0.3253646,
#    'tags': {'amenity': 'restaurant',
#     'name': 'The Ferry',
#     'postal_code': 'KT7 0XY'},
#    'type': 'node'},
#   {'id': 27408322,
#    'lat': 51.5116423,
#    'lon': -0.3047879,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '23',
#     'addr:postcode': 'W5 5DB',
#     'addr:street': 'High Street',
#     'amenity': 'restaurant',
#     'cuisine': 'tex-mex',
#     'name': 'Chimichanga'},
#    'type': 'node'},
#   {'id': 31313905,
#    'lat': 51.5145625,
#    'lon': -0.1488929,
#    'tags': {'amenity': 'restaurant', 'operator': 'Subway'},
#    'type': 'node'},
#   {'id': 31315473,
#    'lat': 51.5112982,
#    'lon': -0.1221602,
#    'tags': {'addr:city': 'London',
#     'amenity': 'restaurant',
#     'cuisine': 'asian',
#     'name': 'Wagamama',
#     'postal_code': 'WC2E 7PG',
#     'source': 'knowledge'},
#    'type': 'node'},
#   {'id': 36138571,
#    'lat': 51.3719881,
#    'lon': -0.1508364,
#    'tags': {'amenity': 'restaurant', 'name': 'The Grange'},
#    'type': 'node'},
#   {'id': 45293688,
#    'lat': 51.5939208,
#    'lon': 0.2346712,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'eat_in': 'yes',
#     'name': 'Bombay Palace',
#     'takeaway': 'yes'},
#    'type': 'node'},
#   {'id': 48745234,
#    'lat': 51.6755746,
#    'lon': 0.0623495,
#    'tags': {'addr:street': 'Wakes Arms Roundabout',
#     'amenity': 'restaurant',
#     'cuisine': 'steak_house',
#     'name': 'Miller & Carter',
#     'source': 'http://www.guardian-series.co.uk/news/9279483.EPPING_FOREST__Landmark_restaurant_changes_hands/',
#     'website': 'http://www.millerandcarter.co.uk/millerandcartereppingforest/'},
#    'type': 'node'},
#   {'id': 59932133,
#    'lat': 51.3777084,
#    'lon': -0.0252881,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'La Rioja - closed'},
#    'type': 'node'},
#   {'id': 65095110,
#    'lat': 51.4256335,
#    'lon': -0.0486072,
#    'tags': {'addr:housenumber': '94',
#     'addr:postcode': 'SE26 5JX',
#     'addr:street': 'Sydenham Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'diet:gluten_free': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Tratorria Raffaele',
#     'phone': '+44 20 8778 6262',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 96008565,
#    'lat': 51.5340961,
#    'lon': -0.0560633,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.4c',
#     'name': 'Bistroteque'},
#    'type': 'node'},
#   {'id': 107509923,
#    'lat': 51.4766863,
#    'lon': 0.2954951,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': 'Magno Cafe'},
#    'type': 'node'},
#   {'id': 108035514,
#    'lat': 51.4753107,
#    'lon': -0.1312456,
#    'tags': {'addr:housenumber': '339-343',
#     'addr:postcode': 'SW8 2JH',
#     'addr:street': 'Wandsworth Road',
#     'alt_name': 'Atoca',
#     'amenity': 'restaurant',
#     'cuisine': 'portuguese',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484663',
#     'fhrs:inspectiondate': '2011-09-29',
#     'fhrs:rating': '4',
#     'name': 'A toca',
#     'note': 'FHRS thinks name=Atoca here'},
#    'type': 'node'},
#   {'id': 128348464,
#    'lat': 51.4871719,
#    'lon': -0.1445137,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'indian', 'name': 'Akbars'},
#    'type': 'node'},
#   {'id': 130159372,
#    'lat': 51.4178872,
#    'lon': -0.1778666,
#    'tags': {'addr:housenumber': '12-14',
#     'addr:postcode': 'SW19 2NX',
#     'addr:street': 'Christchurch Road',
#     'amenity': 'restaurant',
#     'fhrs:id': '505254',
#     'name': 'Venus'},
#    'type': 'node'},
#   {'id': 130159445,
#    'lat': 51.4182511,
#    'lon': -0.1782185,
#    'tags': {'addr:housenumber': '186A',
#     'addr:postcode': 'SW19 2BN',
#     'addr:street': 'High Street Colliers Wood',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:id': '505276',
#     'name': 'Corleone'},
#    'type': 'node'},
#   {'id': 130159480,
#    'lat': 51.4176516,
#    'lon': -0.1778237,
#    'tags': {'addr:housenumber': '26',
#     'addr:postcode': 'SW19 2NX',
#     'addr:street': 'Christchurch Road',
#     'amenity': 'restaurant',
#     'fhrs:id': '200131',
#     'name': 'Spice of Raj'},
#    'type': 'node'},
#   {'id': 130216826,
#    'lat': 51.4135318,
#    'lon': -0.1782626,
#    'tags': {'addr:housename': 'Tandem Centre',
#     'addr:postcode': 'SW19 2TY',
#     'addr:street': 'Tandem Way',
#     'addr:unit': '12',
#     'amenity': 'restaurant',
#     'fhrs:id': '531002',
#     'name': "Nando's"},
#    'type': 'node'},
#   {'id': 130226830,
#    'lat': 51.4130802,
#    'lon': -0.1836687,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.5c',
#     'name': 'Mama Rosa'},
#    'type': 'node'},
#   {'id': 132957893,
#    'lat': 51.4651993,
#    'lon': -0.1291139,
#    'tags': {'addr:housenumber': '3',
#     'addr:street': 'Bedford Road',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '482987',
#     'fhrs:inspectiondate': '2012-01-23',
#     'fhrs:rating': '4',
#     'name': 'Alba',
#     'postal_code': 'SW4 7SH'},
#    'type': 'node'},
#   {'id': 132978018,
#    'lat': 51.4629815,
#    'lon': -0.1239136,
#    'tags': {'addr:housenumber': '118',
#     'addr:postcode': 'SW4 7SE',
#     'addr:street': 'Ferndale Road',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'dontimport:fhrs:addrline1': '118 Ferndale Road',
#     'dontimport:fhrs:addrline2': 'London',
#     'dontimport:fhrs:businesstype': 'Pub/bar/nightclub',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484095',
#     'fhrs:inspectiondate': '2011-10-28',
#     'fhrs:rating': '1',
#     'name': 'Ferndales',
#     'opening_hours': 'We-Su 18:00-22:00'},
#    'type': 'node'},
#   {'id': 160566891,
#    'lat': 51.5245685,
#    'lon': -0.0356241,
#    'tags': {'amenity': 'restaurant', 'name': "Nando's", 'source': 'survey'},
#    'type': 'node'},
#   {'id': 169355678,
#    'lat': 51.4991982,
#    'lon': -0.1378935,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Bon Gusto'},
#    'type': 'node'},
#   {'id': 169368767,
#    'lat': 51.4986224,
#    'lon': -0.1372663,
#    'tags': {'addr:housenumber': '45',
#     'addr:postcode': 'SW1E 6BS',
#     'addr:street': 'Buckingham Gate',
#     'alt_name': 'Zander Bar',
#     'amenity': 'restaurant',
#     'email': 'westminster.reservations@bankrestaurants.com',
#     'name': 'Bank Restaurant & Bar',
#     'phone': '+44 20 76306644',
#     'website': 'www.individualrestaurants.com'},
#    'type': 'node'},
#   {'id': 169368965,
#    'lat': 51.4988578,
#    'lon': -0.1376903,
#    'tags': {'amenity': 'restaurant', 'name': 'Quilton'},
#    'type': 'node'},
#   {'id': 180403503,
#    'lat': 51.5186204,
#    'lon': -0.1214512,
#    'tags': {'amenity': 'restaurant', 'name': 'Spaghetti House'},
#    'type': 'node'},
#   {'id': 187284060,
#    'lat': 51.4427534,
#    'lon': -0.1667732,
#    'tags': {'addr:housenumber': '198-200',
#     'addr:postcode': 'SW17 7HR',
#     'addr:street': 'Trinity Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:id': '297020',
#     'name': 'Pizza Express',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 210788665,
#    'lat': 51.6310288,
#    'lon': -0.336437,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.6a',
#     'name': 'The Alpine'},
#    'type': 'node'},
#   {'id': 212601199,
#    'lat': 51.3201867,
#    'lon': -0.2505759,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.6a',
#     'name': 'South Hatch'},
#    'type': 'node'},
#   {'id': 224162937,
#    'lat': 51.4651012,
#    'lon': 0.0092383,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': "Bianco's"},
#    'type': 'node'},
#   {'id': 242554852,
#    'lat': 51.5897455,
#    'lon': -0.105235,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '27',
#     'addr:street': 'Turnpike Lane',
#     'amenity': 'restaurant',
#     'cuisine': 'Mauritian',
#     'name': 'Le Chamarel'},
#    'type': 'node'},
#   {'id': 245433525,
#    'lat': 51.6783282,
#    'lon': -0.0796137,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'carvery',
#     'name': 'Whitewebbs House',
#     'operator': 'Toby'},
#    'type': 'node'},
#   {'id': 247957987,
#    'lat': 51.505166,
#    'lon': -0.1165376,
#    'tags': {'addr:postcode': 'SE1 8XX',
#     'addr:street': 'Belvedere Road',
#     'amenity': 'restaurant',
#     'cuisine': 'dimsum',
#     'name': 'Ping Pong',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 247957988,
#    'lat': 51.5055251,
#    'lon': -0.1176917,
#    'tags': {'addr:postcode': 'SE1 8XX',
#     'addr:street': 'Festival Terrace',
#     'amenity': 'restaurant',
#     'contact:phone': '+44 20 7620 328',
#     'cuisine': 'brazilian',
#     'name': 'Las Iguanas',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Entrance is unavailable.'},
#    'type': 'node'},
#   {'id': 248443149,
#    'lat': 51.5366022,
#    'lon': -0.0789765,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Waterhouse',
#     'source': 'local knowledge'},
#    'type': 'node'},
#   {'id': 248932671,
#    'lat': 51.462607,
#    'lon': -0.1378996,
#    'tags': {'addr:housenumber': '63-67',
#     'addr:postcode': 'SW4 0BD',
#     'addr:street': 'Venn Street',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484636',
#     'fhrs:inspectiondate': '2012-12-20',
#     'fhrs:rating': '3',
#     'name': 'Gastro'},
#    'type': 'node'},
#   {'id': 248933563,
#    'lat': 51.4631322,
#    'lon': -0.1405744,
#    'tags': {'addr:city': 'Clapham, London',
#     'addr:housenumber': '32',
#     'addr:postcode': 'SW4 0JE',
#     'addr:street': 'The Pavement',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484590',
#     'fhrs:inspectiondate': '2013-02-14',
#     'fhrs:rating': '4',
#     'name': 'No. 32 The Old Town',
#     'opening_hours': '09:00 - 23:00',
#     'toilets': 'yes',
#     'toilets:access': 'customers'},
#    'type': 'node'},
#   {'id': 249573138,
#    'lat': 51.4917587,
#    'lon': -0.2622862,
#    'tags': {'amenity': 'restaurant', 'name': 'Foxlow'},
#    'type': 'node'},
#   {'id': 253267060,
#    'lat': 51.3758148,
#    'lon': -0.409135,
#    'tags': {'amenity': 'restaurant'},
#    'type': 'node'},
#   {'id': 253364552,
#    'lat': 51.3833541,
#    'lon': -0.4171551,
#    'tags': {'amenity': 'restaurant',
#     'amenity:disused': 'pub',
#     'cuisine': 'pizza',
#     'name': "Zio's"},
#    'type': 'node'},
#   {'id': 253469668,
#    'lat': 51.3680652,
#    'lon': -0.3965782,
#    'tags': {'amenity': 'restaurant', 'created_by': 'JOSM'},
#    'type': 'node'},
#   {'id': 255008099,
#    'lat': 51.5796288,
#    'lon': -0.1230838,
#    'tags': {'amenity': 'restaurant', 'name': 'Arocaria'},
#    'type': 'node'},
#   {'id': 255135822,
#    'lat': 51.3317299,
#    'lon': -0.2709857,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': 'Sicily'},
#    'type': 'node'},
#   {'id': 255136127,
#    'lat': 51.3332245,
#    'lon': -0.2692426,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'french',
#     'name': 'Cafe Rouge'},
#    'type': 'node'},
#   {'id': 255136405,
#    'lat': 51.3335926,
#    'lon': -0.2656697,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.8a',
#     'name': 'Ask'},
#    'type': 'node'},
#   {'id': 255136673,
#    'lat': 51.3341469,
#    'lon': -0.2665647,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.8a',
#     'name': 'Jimmy Spice'},
#    'type': 'node'},
#   {'id': 255136777,
#    'lat': 51.3338734,
#    'lon': -0.2670367,
#    'tags': {'amenity': 'restaurant', 'name': "Nando's"},
#    'type': 'node'},
#   {'id': 256366752,
#    'lat': 51.5281942,
#    'lon': -0.0815619,
#    'tags': {'amenity': 'restaurant', 'name': 'Fever Tree'},
#    'type': 'node'},
#   {'id': 257811613,
#    'lat': 51.6595558,
#    'lon': -0.0872645,
#    'tags': {'amenity': 'restaurant', 'name': 'Chaseside', 'note': 'Indian'},
#    'type': 'node'},
#   {'id': 257811796,
#    'lat': 51.6594016,
#    'lon': -0.0879064,
#    'tags': {'amenity': 'restaurant', 'name': 'Enzos'},
#    'type': 'node'},
#   {'id': 259086194,
#    'lat': 51.5101455,
#    'lon': -0.039377,
#    'tags': {'addr:city': 'London',
#     'addr:housename': 'La Figa Restaurant, The Mosaic Building',
#     'addr:housenumber': '45',
#     'addr:postcode': 'E14',
#     'addr:street': 'Narrow Street',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'La Figa',
#     'opening_hours': 'url:http://www.lafigarestaurant.co.uk/contact',
#     'phone': '+44 20 7790 0077',
#     'takeaway': 'yes',
#     'website': 'http://www.lafigarestaurant.co.uk'},
#    'type': 'node'},
#   {'id': 259569252,
#    'lat': 51.488391,
#    'lon': -0.137515,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '34',
#     'addr:street': 'Lupus Street',
#     'amenity': 'restaurant',
#     'cuisine': 'tapas',
#     'fhrs:confidence_management': '10',
#     'fhrs:hygiene': '15',
#     'fhrs:id': '413404',
#     'fhrs:local_authority_id': '01180/0034/0/000',
#     'fhrs:rating': '2',
#     'fhrs:rating_date': '2013-06-25',
#     'fhrs:structural': '10',
#     'name': 'Goya',
#     'outdoor_seating': 'yes',
#     'postal_code': 'SW1V 3EB',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 261269878,
#    'lat': 51.528482,
#    'lon': -0.0512761,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': 'The Gondola'},
#    'type': 'node'},
#   {'id': 261269898,
#    'lat': 51.5283028,
#    'lon': -0.0512585,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': 'Thai Garden'},
#    'type': 'node'},
#   {'id': 262411966,
#    'lat': 51.5203402,
#    'lon': -0.0525884,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.8c',
#     'cuisine': 'chinese',
#     'name': 'Red Dragon'},
#    'type': 'node'},
#   {'id': 262414041,
#    'lat': 51.6338965,
#    'lon': 0.010318,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'chinese', 'name': "Chong's"},
#    'type': 'node'},
#   {'id': 262414042,
#    'lat': 51.6338674,
#    'lon': 0.0102371,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': "Macey's Grill Room & Piano Bar"},
#    'type': 'node'},
#   {'id': 262414043,
#    'lat': 51.6338359,
#    'lon': 0.0101567,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '162-164',
#     'addr:postcode': 'E4 6AN',
#     'addr:street': 'Station Road',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'Waltham Forest',
#     'fhrs:id': '514297',
#     'fhrs:local_authority_id': '222',
#     'name': "L'Artista",
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 262562858,
#    'lat': 51.5032228,
#    'lon': -0.0596251,
#    'tags': {'addr:housenumber': '81',
#     'addr:postcode': 'E1W 2YN',
#     'addr:street': 'Wapping High Street',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Il Bordello',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 262565580,
#    'lat': 51.5062917,
#    'lon': -0.1170999,
#    'tags': {'addr:city': 'London',
#     'addr:postcode': 'SE1 8XX',
#     'addr:street': 'Riverside Level 1',
#     'amenity': 'restaurant',
#     'name': 'Giraffe',
#     'opening_hours': 'Mo-Th 08:00-23:00;Fr 08:00-23:30;Sa 09:00-23:30;Su 09:00-22:30',
#     'phone': '\u200e+442070426900',
#     'website': 'http://www.giraffe.net'},
#    'type': 'node'},
#   {'id': 262565828,
#    'lat': 51.4887868,
#    'lon': -0.1371964,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '46',
#     'addr:street': 'Moreton Street',
#     'amenity': 'restaurant',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '5',
#     'fhrs:id': '428103',
#     'fhrs:local_authority_id': '01444/0046/0/000',
#     'fhrs:rating': '4',
#     'fhrs:rating_date': '2010-07-19',
#     'fhrs:structural': '10',
#     'name': 'Pizza Express',
#     'payment:american_express': 'yes',
#     'postal_code': 'SW1V 2PB',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 262637191,
#    'lat': 51.5621052,
#    'lon': -0.0772243,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '71 - 73',
#     'addr:postcode': 'N16 0AS',
#     'addr:street': 'Stoke Newington Church Street',
#     'amenity': 'restaurant',
#     'cuisine': 'steak,_modern_british,_gastropub',
#     'name': 'Foxlow',
#     'takeaway': 'no',
#     'toilets': 'yes',
#     'toilets:access': 'customers'},
#    'type': 'node'},
#   {'id': 264137221,
#    'lat': 51.505619,
#    'lon': -0.054029,
#    'tags': {'amenity': 'restaurant',
#     'name': 'River View Restaurant',
#     'website': 'http://www.riverview-restaurant.com/'},
#    'type': 'node'},
#   {'id': 264498970,
#    'lat': 51.6017494,
#    'lon': -0.1935144,
#    'tags': {'amenity': 'restaurant', 'name': "Ahir Lorenzo's"},
#    'type': 'node'},
#   {'id': 264515720,
#    'lat': 51.5178558,
#    'lon': -0.1187798,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Pizza Express',
#     'payment:american_express': 'yes'},
#    'type': 'node'},
#   {'id': 264587384,
#    'lat': 51.5222711,
#    'lon': -0.0447505,
#    'tags': {'addr:housenumber': '237',
#     'addr:street': 'Mile End Road',
#     'amenity': 'restaurant',
#     'name': "Verdi's",
#     'old_name': 'R Bar'},
#    'type': 'node'},
#   {'id': 264803330,
#    'lat': 51.4872503,
#    'lon': -0.1115497,
#    'tags': {'addr:housenumber': '314',
#     'addr:postcode': 'SE11 4LD',
#     'addr:street': 'Kennington Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484200',
#     'fhrs:inspectiondate': '2014-04-03',
#     'fhrs:rating': '5',
#     'name': 'Pizza Express',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 264803332,
#    'lat': 51.4873118,
#    'lon': -0.1111439,
#    'tags': {'addr:housenumber': '343',
#     'addr:postcode': 'SE11 4QE',
#     'addr:street': 'Kennington Road',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484205',
#     'fhrs:inspectiondate': '2013-02-14',
#     'fhrs:rating': '5',
#     'name': 'Pizza Hut'},
#    'type': 'node'},
#   {'id': 265124955,
#    'lat': 51.5143857,
#    'lon': -0.1579812,
#    'tags': {'addr:housenumber': '32',
#     'addr:postcode': 'W1H 7EG',
#     'addr:street': 'Bryanston Street',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'La Porte des Indes',
#     'phone': '+44-20-72240055'},
#    'type': 'node'},
#   {'id': 265255759,
#    'lat': 51.5101708,
#    'lon': -0.2879784,
#    'tags': {'amenity': 'restaurant', 'name': "Nando's"},
#    'type': 'node'},
#   {'id': 265649514,
#    'lat': 51.5416421,
#    'lon': -0.1570131,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10',
#     'name': 'Lemonia',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 265662788,
#    'lat': 51.4957287,
#    'lon': -0.1419336,
#    'tags': {'addr:housenumber': '314-316',
#     'addr:postcode': 'SW1V 1AA',
#     'addr:street': 'Vauxhall Bridge Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:id': '413527',
#     'name': 'Il Posto',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 265662939,
#    'lat': 51.4957754,
#    'lon': -0.1419631,
#    'tags': {'addr:housenumber': '318',
#     'addr:postcode': 'SW1V 1AA',
#     'addr:street': 'Vauxhall Bridge Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'fhrs:id': '413528',
#     'name': 'Victoria Tandoori',
#     'source': 'survey',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 266416976,
#    'lat': 51.4955582,
#    'lon': -0.0068108,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'indian', 'name': 'Memsahib'},
#    'type': 'node'},
#   {'id': 266481949,
#    'lat': 51.5109443,
#    'lon': -0.1393778,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '4',
#     'addr:postcode': 'W1B 4BS',
#     'addr:street': 'Heddon Street',
#     'amenity': 'restaurant',
#     'name': 'Aubaine',
#     'website': 'http://www.aubaine.co.uk'},
#    'type': 'node'},
#   {'id': 267971989,
#    'lat': 51.5717552,
#    'lon': -0.1667879,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'name': 'The Brew House'},
#    'type': 'node'},
#   {'id': 269148496,
#    'lat': 51.537255,
#    'lon': 0.0127153,
#    'tags': {'addr:housenumber': '81',
#     'addr:street': 'Portway',
#     'amenity': 'restaurant',
#     'name': 'Black Sea Restaurant',
#     'phone': '02082579034'},
#    'type': 'node'},
#   {'id': 270420476,
#    'lat': 51.506724,
#    'lon': -0.041625,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Pizza Lounge',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 271409937,
#    'lat': 51.4997405,
#    'lon': -0.026204,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '32',
#     'addr:postcode': 'E14 8LW',
#     'addr:street': 'Westferry Road',
#     'amenity': 'restaurant',
#     'name': 'Clifton Restaurant'},
#    'type': 'node'},
#   {'id': 271949508,
#    'lat': 51.5130584,
#    'lon': -0.1422503,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'steak_house',
#     'name': 'Goodmans',
#     'warning': 'service charge included'},
#    'type': 'node'},
#   {'id': 271949545,
#    'lat': 51.5133258,
#    'lon': -0.1423597,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Pollen Street Social',
#     'toilets': 'yes',
#     'toilets:access': 'customers',
#     'wheelchair': 'limited',
#     'wheelchair_toilet': 'no'},
#    'type': 'node'},
#   {'id': 271950666,
#    'lat': 51.5144147,
#    'lon': -0.1274941,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Thai Square',
#     'wheelchair': 'limited'},
#    'type': 'node'},
#   {'id': 272077156,
#    'lat': 51.4920195,
#    'lon': -0.140075,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': 'Uno'},
#    'type': 'node'},
#   {'id': 272499359,
#    'lat': 51.4861072,
#    'lon': -0.0136578,
#    'tags': {'amenity': 'restaurant', 'name': 'Elephant Royale'},
#    'type': 'node'},
#   {'id': 273542295,
#    'lat': 51.4614013,
#    'lon': -0.11448,
#    'tags': {'addr:housenumber': '447',
#     'addr:street': 'Coldharbour Lane',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '483006',
#     'fhrs:inspectiondate': '2013-10-09',
#     'fhrs:rating': '5',
#     'name': 'Satay Bar',
#     'postal_code': 'SW9 8LP'},
#    'type': 'node'},
#   {'id': 275405499,
#    'lat': 51.49107,
#    'lon': -0.135199,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'argentinian',
#     'name': 'Moo',
#     'outdoor_seating': 'yes',
#     'postal_code': 'SW1V 2TA'},
#    'type': 'node'},
#   {'id': 276076130,
#    'lat': 51.4924309,
#    'lon': -0.1399891,
#    'tags': {'amenity': 'restaurant', 'name': 'Absolute Thyme'},
#    'type': 'node'},
#   {'id': 276084595,
#    'lat': 51.4907614,
#    'lon': -0.1508557,
#    'tags': {'addr:city': 'London',
#     'addr:housename': 'No. 11',
#     'addr:housenumber': '11',
#     'addr:postcode': 'SW1W 8NA',
#     'addr:street': 'Pimlico Road',
#     'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'description': 'Private dining available',
#     'designation': 'European',
#     'disabled': 'limited',
#     'disabled:description': 'Ground floor only',
#     'fhrs:confidence_management': '10',
#     'fhrs:hygiene': '0',
#     'fhrs:id': '411656',
#     'fhrs:local_authority_id': '00518/0011/0/000',
#     'fhrs:rating': '4',
#     'fhrs:rating_date': '2013-04-16',
#     'fhrs:structural': '5',
#     'name': 'No. 11',
#     'old_name': 'The Union',
#     'source': 'http://no11pimlicoroad.co.uk',
#     'source:postcode': 'FSA Food Hygiene Ratings Database',
#     'toilets': 'yes',
#     'toilets:access': 'customers',
#     'website': 'http://no11pimlicoroad.co.uk',
#     'wifi': 'free'},
#    'type': 'node'},
#   {'id': 276676950,
#    'lat': 51.4889736,
#    'lon': -0.1369115,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Pimlico Tandoori',
#     'postal_code': 'SW1V 2PB'},
#    'type': 'node'},
#   {'id': 277910542,
#    'lat': 51.5149377,
#    'lon': -0.0635211,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': 'Mirch Masala'},
#    'type': 'node'},
#   {'id': 277910563,
#    'lat': 51.5146239,
#    'lon': -0.0622095,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'JOSM',
#     'name': 'Shalamar Kebab House'},
#    'type': 'node'},
#   {'id': 278273595,
#    'lat': 51.5076256,
#    'lon': -0.0711841,
#    'tags': {'addr:housename': 'Ivory House',
#     'addr:street': 'St Katharines Dock',
#     'amenity': 'restaurant',
#     'name': 'Medieval Banquet',
#     'phone': '+44 20 7480 5353',
#     'postal_code': 'E1W 1BP',
#     'website': 'http://www.medievalbanquet.com'},
#    'type': 'node'},
#   {'id': 278294821,
#    'lat': 51.5063682,
#    'lon': -0.0705255,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.9c',
#     'name': 'Mala'},
#    'type': 'node'},
#   {'id': 279857098,
#    'lat': 51.5134147,
#    'lon': 0.0118549,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '57',
#     'addr:postcode': 'E16 1EE',
#     'addr:street': 'Hallsville Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': "Amir's Restaurant",
#     'old_name': 'The Halsville Tavern'},
#    'type': 'node'},
#   {'id': 280835741,
#    'lat': 51.4833439,
#    'lon': -0.1695887,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10',
#     'name': 'Cheyne Walk Brasserie'},
#    'type': 'node'},
#   {'id': 281426069,
#    'lat': 51.5117329,
#    'lon': -0.1876375,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '108-110Queensway',
#     'amenity': 'restaurant',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '10',
#     'fhrs:id': '414045',
#     'fhrs:local_authority_id': '01512/0108/0/000',
#     'fhrs:rating': '4',
#     'fhrs:rating_date': '2009-02-05',
#     'fhrs:structural': '0',
#     'name': 'Bella Italia',
#     'postal_code': 'W2 3RR',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 281426392,
#    'lat': 51.5125832,
#    'lon': -0.1874197,
#    'tags': {'amenity': 'restaurant', 'name': 'Ristorante Italiano'},
#    'type': 'node'},
#   {'id': 281428200,
#    'lat': 51.5151177,
#    'lon': -0.1917636,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10',
#     'name': "L'Accento"},
#    'type': 'node'},
#   {'id': 282113431,
#    'lat': 51.5075201,
#    'lon': 0.0207124,
#    'tags': {'addr:city': 'London',
#     'addr:housename': 'Excel Marina',
#     'addr:housenumber': '17',
#     'addr:postcode': 'E16 1AT',
#     'addr:street': 'Western Gateway',
#     'addr:unit': 'Unit 7',
#     'amenity': 'restaurant',
#     'contact:phone': '+44 20 7511 8608',
#     'contact:website': 'http://www.top1forever.co.uk/',
#     'fhrs:id': '782136',
#     'name': 'Top 1 Forever',
#     'phone': '+442075118608',
#     'source:addr': 'FHRS Open Data',
#     'website': 'http://www.top1forever.co.uk/'},
#    'type': 'node'},
#   {'id': 282407250,
#    'lat': 51.5060253,
#    'lon': 0.0164465,
#    'tags': {'addr:city': 'London',
#     'addr:housename': 'Waterfront Studios',
#     'addr:housenumber': '1',
#     'addr:postcode': 'E16 1AH',
#     'addr:street': 'Dock Road',
#     'amenity': 'restaurant',
#     'contact:email': 'royaldocks@nakhonthai.co.uk',
#     'contact:facebook': 'http://www.facebook.com/pages/NAKHON-THAI-RESTAURANT/285761615461',
#     'contact:phone': '+44 20 7474 5510',
#     'contact:twitter': '@thai_nakhon',
#     'contact:website': 'http://nakhonthai.co.uk/',
#     'cuisine': 'thai',
#     'fhrs:authority': 'Newham',
#     'fhrs:id': '640179',
#     'fhrs:local_authority_id': '05/00150/FOOD',
#     'name': 'Nakhon Tai Waterfront',
#     'ref:NPLG:UPRN:1': '010034509636',
#     'source:addr': 'FHRS Open Data',
#     'takeaway': 'yes'},
#    'type': 'node'},
#   {'id': 282686484,
#    'lat': 51.5056639,
#    'lon': -0.1151021,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': 'Pizza Express',
#     'postal_code': 'SE1 8YP',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 282686485,
#    'lat': 51.5052279,
#    'lon': -0.1167364,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Feng Sushi',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Need assistance to open the door to the toilet.'},
#    'type': 'node'},
#   {'id': 282686488,
#    'lat': 51.5058176,
#    'lon': -0.117588,
#    'tags': {'addr:city': 'London',
#     'addr:postcode': 'SE1 8XX',
#     'addr:street': 'Royal Festival Hall',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Strada',
#     'opening_hours': 'Mo-We 08:00-23:00;Th-Sa 08:00-24:00;Su 11:30-22:00',
#     'phone': '+4420 7401 9126',
#     'website': 'http://www.strada.co.uk/italian-restaurant/royal-festival-hall',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 282859047,
#    'lat': 51.505445,
#    'lon': 0.0261154,
#    'tags': {'amenity': 'restaurant', 'name': 'So! Restaurant Bar'},
#    'type': 'node'},
#   {'id': 286509356,
#    'lat': 51.4962331,
#    'lon': -0.0825069,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'Sanh Hing'},
#    'type': 'node'},
#   {'id': 286509357,
#    'lat': 51.4961827,
#    'lon': -0.0825831,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Tower Tandoori'},
#    'type': 'node'},
#   {'id': 287453551,
#    'lat': 51.5006223,
#    'lon': -0.0914796,
#    'tags': {'amenity': 'restaurant', 'name': 'Simply Indian'},
#    'type': 'node'},
#   {'id': 287458238,
#    'lat': 51.4925438,
#    'lon': -0.0717795,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': 'Arancia'},
#    'type': 'node'},
#   {'id': 288598376,
#    'lat': 51.4995651,
#    'lon': -0.2645088,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Thai Thai Café',
#     'phone': '020 8994 1093'},
#    'type': 'node'},
#   {'id': 290128614,
#    'lat': 51.5057051,
#    'lon': -0.117683,
#    'tags': {'addr:city': 'London',
#     'addr:housename': 'unit 7 riverside level 1',
#     'addr:housenumber': 'Riverside Level',
#     'addr:postcode': 'SE1 8XX',
#     'addr:street': 'Royal Festival Hall',
#     'amenity': 'restaurant',
#     'capacity': '160',
#     'cuisine': 'asian',
#     'name': 'Wagamama',
#     'opening_hours': 'Mo-Sa 11:00-23:00;Su 11:00-22:00',
#     'phone': '+442070210877',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 291667665,
#    'lat': 51.4383116,
#    'lon': -0.1562741,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': "Bodean's"},
#    'type': 'node'},
#   {'id': 292384037,
#    'lat': 51.4974573,
#    'lon': -0.1296741,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '30',
#     'addr:postcode': 'SW1P 3BU',
#     'addr:street': 'Great Smith Street',
#     'amenity': 'restaurant',
#     'cuisine': 'indian;curry',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '5',
#     'fhrs:id': '413742',
#     'fhrs:local_authority_id': '01378/0030/3/000',
#     'fhrs:rating': '5',
#     'fhrs:rating_date': '2012-01-06',
#     'fhrs:structural': '5',
#     'name': 'The Cinnamon Club',
#     'outdoor_seating': 'no',
#     'phone': '+44 20 7222 2555',
#     'postal_code': 'SW1P 3BU',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database',
#     'website': 'http://www.cinnamonclub.com/'},
#    'type': 'node'},
#   {'id': 293018578,
#    'lat': 51.3656646,
#    'lon': 0.0531852,
#    'tags': {'amenity': 'restaurant', 'name': 'Chapter One'},
#    'type': 'node'},
#   {'id': 293477394,
#    'lat': 51.4266607,
#    'lon': 0.0961746,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Horse and Groom',
#     'operator': 'Harvester',
#     'toilets': 'yes',
#     'toilets:access': 'customers'},
#    'type': 'node'},
#   {'id': 293805811,
#    'lat': 51.5360507,
#    'lon': -0.1464791,
#    'tags': {'addr:housenumber': '127-129',
#     'addr:street': 'Parkway',
#     'amenity': 'restaurant',
#     'name': 'York & Albany',
#     'postal_code': 'NW1 7PS',
#     'website': 'http://www.gordonramsay.com/yorkandalbany',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 294102638,
#    'lat': 51.5367494,
#    'lon': -0.1421648,
#    'tags': {'addr:housenumber': '98',
#     'addr:postcode': 'NW1 7HT',
#     'addr:street': 'Arlington Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Locanda Canton',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 294102721,
#    'lat': 51.5367912,
#    'lon': -0.1420045,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese'},
#    'type': 'node'},
#   {'id': 295975610,
#    'lat': 51.5137136,
#    'lon': -0.0757885,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'asia', 'name': 'Itsu'},
#    'type': 'node'},
#   {'id': 295975928,
#    'lat': 51.513355,
#    'lon': -0.0908549,
#    'tags': {'amenity': 'restaurant',
#     'level': '7',
#     'name': "Coq d'Argent",
#     'note': 'Rooftop Garden',
#     'outdoor_seating': 'yes'},
#    'type': 'node'},
#   {'id': 296484518,
#    'lat': 51.4924822,
#    'lon': -0.2780734,
#    'tags': {'amenity': 'restaurant', 'name': 'Napa'},
#    'type': 'node'},
#   {'id': 296484947,
#    'lat': 51.4935053,
#    'lon': -0.2675256,
#    'tags': {'amenity': 'restaurant', 'name': 'Cucina China Buffet'},
#    'type': 'node'},
#   {'id': 296491138,
#    'lat': 51.5080583,
#    'lon': -0.0951602,
#    'tags': {'addr:housenumber': '2a',
#     'addr:postcode': 'SE1 9HA',
#     'addr:street': 'Southwark Bridge Road',
#     'addr:unit': '1-2',
#     'amenity': 'restaurant',
#     'contact:phone': '+44 207 6200162',
#     'cuisine': 'greek',
#     'name': 'The Real Greek',
#     'opening_hours': 'Mo-Su 12:00-22:30'},
#    'type': 'node'},
#   {'id': 296491141,
#    'lat': 51.5082022,
#    'lon': -0.096,
#    'tags': {'addr:housename': 'Benbow House',
#     'addr:housenumber': '24',
#     'addr:postcode': 'SE1 9DS',
#     'addr:street': 'New Globe Walk',
#     'amenity': 'restaurant',
#     'name': 'Pizza Express',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 296610128,
#    'lat': 51.5117911,
#    'lon': -0.0931398,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Wagamama',
#     'phone': '0207 248 5766',
#     'postcode': 'EC4V 2BH',
#     'website': 'http://www.wagamama.com/locations/showlocation/550'},
#    'type': 'node'},
#   {'id': 296614811,
#    'lat': 51.5097312,
#    'lon': -0.0802923,
#    'tags': {'addr:street': 'Byward Street',
#     'amenity': 'restaurant',
#     'name': 'Pizza Express'},
#    'type': 'node'},
#   {'id': 296614820,
#    'lat': 51.5111253,
#    'lon': -0.079329,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '14',
#     'addr:postcode': 'EC3R 7NA',
#     'addr:street': 'New London Street',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'City of London Corporation',
#     'fhrs:id': '926273',
#     'fhrs:local_authority_id': 'PI/000030310',
#     'name': 'Roma',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 296615758,
#    'lat': 51.5053308,
#    'lon': -0.0801739,
#    'tags': {'addr:housenumber': '2',
#     'addr:street': 'More London Place',
#     'amenity': 'restaurant',
#     'name': 'Strada',
#     'postal_code': 'SE1 2JP',
#     'website': 'http://www.strada.co.uk/locations#59'},
#    'type': 'node'},
#   {'id': 296615761,
#    'lat': 51.5052298,
#    'lon': -0.0802465,
#    'tags': {'addr:housenumber': '2',
#     'addr:street': 'More London Place',
#     'amenity': 'restaurant',
#     'name': 'Dim T',
#     'postal_code': 'SE1 2DB',
#     'website': 'http://www.dimt.co.uk/'},
#    'type': 'node'},
#   {'id': 296615763,
#    'lat': 51.5051331,
#    'lon': -0.0803967,
#    'tags': {'addr:housenumber': '2',
#     'addr:street': 'More London Riverside',
#     'amenity': 'restaurant',
#     'name': 'Gaucho Grill',
#     'phone': '020 7407 5222',
#     'postal_code': 'SE1 2AP',
#     'website': 'http://www.gauchorestaurants.co.uk/restaurants/restaurant.php?id=towerbridge'},
#    'type': 'node'},
#   {'id': 296616818,
#    'lat': 51.5063767,
#    'lon': -0.0718114,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '50',
#     'addr:postcode': 'E1W 1LB',
#     'addr:street': "St Katharine's Way",
#     'amenity': 'restaurant',
#     'name': 'Tradewinds'},
#    'type': 'node'},
#   {'id': 296639103,
#    'lat': 51.5083936,
#    'lon': -0.108242,
#    'tags': {'addr:housenumber': '8th floor',
#     'amenity': 'restaurant',
#     'name': 'Oxo Tower Restaurant'},
#    'type': 'node'},
#   {'id': 297827898,
#    'lat': 51.51338,
#    'lon': -0.171451,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '28',
#     'addr:street': 'Sussex Place',
#     'amenity': 'restaurant',
#     'cuisine': 'international',
#     'fhrs:confidence_management': '10',
#     'fhrs:hygiene': '10',
#     'fhrs:id': '414298',
#     'fhrs:local_authority_id': '01588/0028/0/000',
#     'fhrs:rating': '3',
#     'fhrs:rating_date': '2011-09-06',
#     'fhrs:structural': '10',
#     'name': 'Salt & Honey',
#     'outdoor_seating': 'no',
#     'postal_code': 'W2 2TH',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 298009920,
#    'lat': 51.5064909,
#    'lon': -0.0994396,
#    'tags': {'amenity': 'restaurant', 'name': 'Leon'},
#    'type': 'node'},
#   {'id': 298031178,
#    'lat': 51.4278688,
#    'lon': -0.3551962,
#    'tags': {'amenity': 'restaurant', 'name': 'Hampton Garden'},
#    'type': 'node'},
#   {'id': 298031216,
#    'lat': 51.4265096,
#    'lon': -0.3562708,
#    'tags': {'addr:housenumber': '133',
#     'addr:postcode': 'TW12 1NJ',
#     'addr:street': 'High Street',
#     'amenity': 'restaurant',
#     'fhrs:id': '353854',
#     'name': 'Piazza Firenze',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 298031227,
#    'lat': 51.425968,
#    'lon': -0.356823,
#    'tags': {'amenity': 'restaurant', 'name': "Joe's Bar"},
#    'type': 'node'},
#   {'id': 298031228,
#    'lat': 51.4251568,
#    'lon': -0.3576128,
#    'tags': {'addr:housenumber': '75',
#     'addr:postcode': 'TW12 1NH',
#     'addr:street': 'High Street',
#     'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'fhrs:id': '353267',
#     'name': 'Tin Tin',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 298837293,
#    'lat': 51.4736908,
#    'lon': -0.2511861,
#    'tags': {'addr:housenumber': '375',
#     'addr:postcode': 'SW13 9PY',
#     'addr:street': 'Lonsdale Road',
#     'amenity': 'restaurant',
#     'fhrs:id': '353488',
#     'name': 'Strada',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 298915899,
#    'lat': 51.5239249,
#    'lon': -0.1670188,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '112',
#     'addr:postcode': 'NW1 6UL',
#     'addr:street': 'Lisson Grove',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '0',
#     'fhrs:id': '412992',
#     'fhrs:local_authority_id': '00993/0112/0/001',
#     'fhrs:rating': '4',
#     'fhrs:rating_date': '2012-02-27',
#     'fhrs:structural': '10',
#     'name': 'Marylebone Spice',
#     'phone': '02077246565',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 299424517,
#    'lat': 51.5077538,
#    'lon': 0.0083964,
#    'tags': {'amenity': 'restaurant',
#     'name': "Fatboy's Diner",
#     'website': 'http://www.fatboysdiner.co.uk/'},
#    'type': 'node'},
#   {'id': 299523381,
#    'lat': 51.521809,
#    'lon': -0.1575647,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '131-133',
#     'addr:postcode': 'W1U 6SE',
#     'addr:street': 'Baker Street',
#     'amenity': 'restaurant',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '10',
#     'fhrs:id': '428031',
#     'fhrs:local_authority_id': '01123/0131/0/002',
#     'fhrs:rating': '3',
#     'fhrs:rating_date': '2010-10-18',
#     'fhrs:structural': '10',
#     'name': 'Pizza Express',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 299610713,
#    'lat': 51.5405064,
#    'lon': -0.0957547,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Akari',
#     'opening_hours': 'Mo off; Tu-Fr 17:00-23:00; Sa 12:00-23:00; Su 12:00-22:30',
#     'phone': '02072269943'},
#    'type': 'node'},
#   {'id': 299612702,
#    'lat': 51.5361636,
#    'lon': -0.1038389,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'Cañas y Tapas'},
#    'type': 'node'},
#   {'id': 299615150,
#    'lat': 51.5359926,
#    'lon': -0.1039142,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'mexican', 'name': 'wahaca'},
#    'type': 'node'},
#   {'id': 299615227,
#    'lat': 51.5365176,
#    'lon': -0.1037374,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10b',
#     'cuisine': 'brazilian',
#     'name': 'Rodizio Rico'},
#    'type': 'node'},
#   {'id': 299615313,
#    'lat': 51.5385359,
#    'lon': -0.1025179,
#    'tags': {'addr:housenumber': '119',
#     'addr:postcode': 'N1 1QP',
#     'addr:street': 'Upper Street',
#     'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Isarn',
#     'phone': '02074245153',
#     'website': 'www.isarn.co.uk'},
#    'type': 'node'},
#   {'id': 299615387,
#    'lat': 51.539491,
#    'lon': -0.1026162,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Antepiller',
#     'outdoor_seating': 'yes'},
#    'type': 'node'},
#   {'id': 299615449,
#    'lat': 51.5397161,
#    'lon': -0.1026778,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '140a',
#     'addr:street': 'Upper Street',
#     'amenity': 'restaurant',
#     'cuisine': 'french',
#     'name': 'Le Mercury',
#     'outdoor_seating': 'no',
#     'payment:american_express': 'yes'},
#    'type': 'node'},
#   {'id': 299615477,
#    'lat': 51.53978,
#    'lon': -0.1026842,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'La Porchetta',
#     'outdoor_seating': 'no',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 299615649,
#    'lat': 51.5351424,
#    'lon': -0.1039686,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'burger', 'name': 'Byron'},
#    'type': 'node'},
#   {'id': 299615666,
#    'lat': 51.5348703,
#    'lon': -0.1041977,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10b',
#     'cuisine': 'thai',
#     'name': 'Thai Square'},
#    'type': 'node'},
#   {'id': 299615868,
#    'lat': 51.535348,
#    'lon': -0.1037375,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': 'Pizza Express'},
#    'type': 'node'},
#   {'id': 299615905,
#    'lat': 51.5354294,
#    'lon': -0.1035811,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'mexican', 'name': 'Chipotle'},
#    'type': 'node'},
#   {'id': 299616048,
#    'lat': 51.5379933,
#    'lon': -0.1022755,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Merkaartor 0.12',
#     'cuisine': 'italian',
#     'name': "Carluccio's"},
#    'type': 'node'},
#   {'id': 299616251,
#    'lat': 51.5389098,
#    'lon': -0.1020998,
#    'tags': {'addr:housenumber': '302',
#     'addr:postcode': 'N1 2TU',
#     'addr:street': 'Upper street',
#     'amenity': 'restaurant',
#     'cuisine': 'turkish',
#     'name': 'The Ottoman',
#     'phone': '02073542260'},
#    'type': 'node'},
#   {'id': 299616421,
#    'lat': 51.5389621,
#    'lon': -0.1021021,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10b',
#     'cuisine': 'turkish',
#     'name': 'Pasha'},
#    'type': 'node'},
#   {'id': 300413435,
#    'lat': 51.4909953,
#    'lon': -0.1804225,
#    'tags': {'addr:housenumber': '117/119',
#     'addr:postcode': 'SW7 3RN',
#     'addr:street': 'Old Brompton Road',
#     'amenity': 'restaurant',
#     'cuisine': 'french',
#     'name': 'Bistro K',
#     'website': 'www.bistro-k.co.uk'},
#    'type': 'node'},
#   {'id': 300413484,
#    'lat': 51.4930362,
#    'lon': -0.1759931,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese', 'name': 'Saki II'},
#    'type': 'node'},
#   {'id': 300414628,
#    'lat': 51.4936619,
#    'lon': -0.1751941,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'argentinian',
#     'name': 'El Gaucho'},
#    'type': 'node'},
#   {'id': 300425781,
#    'lat': 51.4937591,
#    'lon': -0.175661,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Papa Roma'},
#    'type': 'node'},
#   {'id': 300425808,
#    'lat': 51.493492,
#    'lon': -0.1757701,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Moti Mahal',
#     'phone': '02075848428'},
#    'type': 'node'},
#   {'id': 300425811,
#    'lat': 51.4931468,
#    'lon': -0.1764815,
#    'tags': {'amenity': 'restaurant', 'name': 'La Bouchée'},
#    'type': 'node'},
#   {'id': 300425812,
#    'lat': 51.4930955,
#    'lon': -0.1766159,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Bella Italia'},
#    'type': 'node'},
#   {'id': 300425858,
#    'lat': 51.4908151,
#    'lon': -0.1828367,
#    'tags': {'addr:housenumber': '154',
#     'addr:street': 'Old Brompton Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Star of India'},
#    'type': 'node'},
#   {'id': 300425867,
#    'lat': 51.4908485,
#    'lon': -0.1836688,
#    'tags': {'amenity': 'restaurant', 'name': 'Bar Asia'},
#    'type': 'node'},
#   {'id': 300500878,
#    'lat': 51.5402184,
#    'lon': -0.1453061,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Wagamama',
#     'source': 'TMJ-Mobile_0.6.2',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 300613142,
#    'lat': 51.4078553,
#    'lon': -0.0252919,
#    'tags': {'amenity': 'restaurant', 'name': 'La Rascasse'},
#    'type': 'node'},
#   {'id': 300613859,
#    'lat': 51.4067324,
#    'lon': -0.0314556,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Risto',
#     'phone': '+44 20 86630881'},
#    'type': 'node'},
#   {'id': 302178354,
#    'lat': 51.5703064,
#    'lon': -0.3395744,
#    'tags': {'addr:housenumber': '51',
#     'addr:postcode': 'HA1 3HT',
#     'addr:street': 'High Street',
#     'amenity': 'restaurant',
#     'name': 'Cafe Cafe Restaurant',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 302397668,
#    'lat': 51.492625,
#    'lon': -0.177454,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'il Falconiere'},
#    'type': 'node'},
#   {'id': 302397670,
#    'lat': 51.4935965,
#    'lon': -0.1677039,
#    'tags': {'addr:housenumber': '104',
#     'addr:street': 'Draycott Avenue',
#     'amenity': 'restaurant',
#     'name': 'Le Suquet',
#     'phone': '02075811785'},
#    'type': 'node'},
#   {'id': 302397673,
#    'lat': 51.4934399,
#    'lon': -0.167172,
#    'tags': {'amenity': 'restaurant', 'name': 'Papillon'},
#    'type': 'node'},
#   {'id': 302397761,
#    'lat': 51.4958983,
#    'lon': -0.1647976,
#    'tags': {'amenity': 'restaurant', 'name': 'Scalini'},
#    'type': 'node'},
#   {'id': 303187448,
#    'lat': 51.4634939,
#    'lon': -0.1329449,
#    'tags': {'addr:housenumber': '59-63',
#     'addr:street': 'Clapham High Street',
#     'amenity': 'restaurant',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '483942',
#     'fhrs:inspectiondate': '2014-03-18',
#     'fhrs:rating': '5',
#     'name': "Nando's",
#     'postal_code': 'SW4 7TG'},
#    'type': 'node'},
#   {'id': 304421989,
#    'lat': 51.5358215,
#    'lon': -0.2442261,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'portuguese',
#     'name': 'Adega Lusitana',
#     'note': 'Used to be the Green Man pub.',
#     'phone': '020 89656443',
#     'postal_code': 'NW10 4TS'},
#    'type': 'node'},
#   {'id': 305476884,
#    'lat': 51.4885913,
#    'lon': -0.1439055,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'french',
#     'name': 'The Contented Vine',
#     'postal_code': 'SW1V 4QQ'},
#    'type': 'node'},
#   {'id': 305481820,
#    'lat': 51.5477974,
#    'lon': -0.1062725,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Standard Tandoori',
#     'payment:american_express': 'yes',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 306042529,
#    'lat': 51.534313,
#    'lon': -0.106562,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'asian',
#     'level': '2',
#     'name': 'Wagamama'},
#    'type': 'node'},
#   {'id': 306042546,
#    'lat': 51.5343272,
#    'lon': -0.106436,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'burger',
#     'level': '2',
#     'name': 'gbk'},
#    'type': 'node'},
#   {'id': 307852577,
# ...
#    'lat': 51.4634296,
#    'lon': -0.1414943,
#    'tags': {'addr:city': 'London',
#     'addr:country': 'GB',
#     'addr:housenumber': '4',
#     'addr:postcode': 'SW4 0JG',
#     'addr:street': 'The Polygon',
#     'amenity': 'restaurant',
#     'cuisine': 'european',
#     'fhrs:authority': 'Lambeth',
#     'fhrs:id': '484592',
#     'fhrs:inspectiondate': '2012-09-18',
#     'fhrs:rating': '5',
#     'name': 'Trinity'},
#    'type': 'node'},
#   {'id': 676862785,
#    'lat': 51.5543584,
#    'lon': -0.1645522,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Bengal Village',
#     'phone': '020 7485 9921',
#     'takeaway': 'yes'},
#    'type': 'node'},
#   {'id': 677225985,
#    'lat': 51.5612609,
#    'lon': -0.3577992,
#    'tags': {'addr:housenumber': '372',
#     'addr:street': 'Northolt Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Curry Mahal',
#     'phone': '02084227976',
#     'start_date': '1976'},
#    'type': 'node'},
#   {'id': 677225987,
#    'lat': 51.5604404,
#    'lon': -0.3581028,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'breakfast',
#     'name': 'Sunshine Café',
#     'name:former': 'Tasty Grill'},
#    'type': 'node'},
#   {'id': 677316017,
#    'lat': 51.4963541,
#    'lon': -0.0827359,
#    'tags': {'addr:housenumber': '87',
#     'addr:street': 'Tower Bridge Road',
#     'amenity': 'restaurant',
#     'name': 'M. Manze',
#     'phone': '020 7407 2985',
#     'postal_code': 'SE1 4TW',
#     'website': 'http://www.manze.co.uk'},
#    'type': 'node'},
#   {'id': 677407791,
#    'lat': 51.4109791,
#    'lon': -0.3011571,
#    'tags': {'addr:housenumber': '105',
#     'addr:postcode': 'KT1 1QY',
#     'addr:street': 'Clarence Street',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'fhrs:id': '361207',
#     'name': 'Pizza Hut',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 677407793,
#    'lat': 51.4106841,
#    'lon': -0.30055,
#    'tags': {'addr:housenumber': '2',
#     'addr:postcode': 'KT2 6QF',
#     'addr:street': 'Old London Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:id': '362026',
#     'name': 'Little Italy',
#     'source:addr': 'FHRS Open Data',
#     'wheelchair': 'limited'},
#    'type': 'node'},
#   {'id': 678896790,
#    'lat': 51.2969939,
#    'lon': -0.3565956,
#    'tags': {'addr:city': 'Fetcham, Leatherhead',
#     'addr:housenumber': '248',
#     'addr:postcode': 'KT22 9JF',
#     'addr:street': 'Cobham Road',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Fetcham Tandoori',
#     'phone': '+44 1372 374927',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'http://fetchamtandoori.com/\r\nUnable to check toilets from outside'},
#    'type': 'node'},
#   {'id': 679126938,
#    'lat': 51.4814907,
#    'lon': -0.2676283,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Grove Park Tandoori'},
#    'type': 'node'},
#   {'id': 679126942,
#    'lat': 51.4814773,
#    'lon': -0.2672742,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'seafood', 'name': 'Reef'},
#    'type': 'node'},
#   {'id': 679967784,
#    'lat': 51.6339926,
#    'lon': -0.1336651,
#    'tags': {'addr:city': 'London',
#     'addr:postcode': 'N14 5HD',
#     'addr:street': 'Chase Side',
#     'amenity': 'restaurant',
#     'cuisine': 'turkish',
#     'name': 'Kervan Sofrasi',
#     'opening_hours': '11:00-23:30',
#     'smoking': 'no',
#     'takeaway': 'yes',
#     'url': 'http://kervan-sofrasi.co.uk'},
#    'type': 'node'},
#   {'id': 679967785,
#    'lat': 51.6334962,
#    'lon': -0.1311776,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '102',
#     'addr:postcode': 'N14 5PH',
#     'addr:street': 'Chase Side',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:authority': 'Enfield',
#     'fhrs:id': '316235',
#     'fhrs:local_authority_id': 'PI/000025857',
#     'name': 'Fantozzi',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 680150064,
#    'lat': 51.5351188,
#    'lon': -0.1213433,
#    'tags': {'addr:housenumber': '90',
#     'addr:street': 'York way',
#     'amenity': 'restaurant',
#     'cuisine': 'british',
#     'name': 'Rotunda',
#     'website': 'www.rotundabarandrestaurant.co.uk'},
#    'type': 'node'},
#   {'id': 681575124,
#    'lat': 51.4510492,
#    'lon': -0.3322117,
#    'tags': {'amenity': 'restaurant', 'name': 'Ma Cuisine'},
#    'type': 'node'},
#   {'id': 681577117,
#    'lat': 51.4510128,
#    'lon': -0.3317158,
#    'tags': {'addr:housenumber': '117',
#     'addr:postcode': 'TW1 1EE',
#     'addr:street': 'London Road',
#     'amenity': 'restaurant',
#     'fhrs:id': '353244',
#     'name': 'La Serenata',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 684079467,
#    'lat': 51.4820077,
#    'lon': -0.4762083,
#    'tags': {'addr:city': 'West Drayton',
#     'addr:country': 'GB',
#     'addr:housenumber': '388',
#     'addr:postcode': 'UB7 0DH',
#     'addr:street': 'Bath Road',
#     'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'London Hong Kong',
#     'website': 'http://www.londonhongkong.co.uk/',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 684666407,
#    'lat': 51.5302912,
#    'lon': -0.1228944,
#    'tags': {'addr:housenumber': '9-11',
#     'addr:street': 'Euston Road',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:id': '516240',
#     'name': 'La Regina',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 684667920,
#    'lat': 51.5303559,
#    'lon': -0.1227338,
#    'tags': {'addr:housenumber': '3',
#     'addr:postcode': 'NW1 2SA',
#     'addr:street': 'Euston Road',
#     'amenity': 'restaurant',
#     'cuisine': 'noodle',
#     'fhrs:id': '426384',
#     'name': 'Chop Chop',
#     'source:addr': 'FHRS Open Data'},
#    'type': 'node'},
#   {'id': 686568571,
#    'lat': 51.504169,
#    'lon': -0.105598,
#    'tags': {'addr:housenumber': '94',
#     'addr:street': 'Isabella street',
#     'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Thai Silk',
#     'postal_code': 'SE1 8DA',
#     'website': 'http://www.thaisilkrestaurant.co.uk'},
#    'type': 'node'},
#   {'id': 687648578,
#    'lat': 51.5116672,
#    'lon': -0.0751904,
#    'tags': {'amenity': 'restaurant', 'name': 'Lazio'},
#    'type': 'node'},
#   {'id': 688159540,
#    'lat': 51.5285285,
#    'lon': -0.1191205,
#    'tags': {'amenity': 'restaurant', 'name': 'Acorn House'},
#    'type': 'node'},
#   {'id': 688688992,
#    'lat': 51.509757,
#    'lon': -0.078376,
#    'tags': {'amenity': 'restaurant', 'name': 'Chez Gerard'},
#    'type': 'node'},
#   {'id': 689212750,
#    'lat': 51.5118999,
#    'lon': -0.1222464,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '18',
#     'addr:postcode': 'WC2E 8RF',
#     'addr:street': 'Covent Garden',
#     'amenity': 'restaurant',
#     'description': 'Bakery and Communal Table',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '10',
#     'fhrs:id': '413561',
#     'fhrs:local_authority_id': '01265/0048/0/000',
#     'fhrs:rating': '2',
#     'fhrs:rating_date': '2012-09-12',
#     'fhrs:structural': '15',
#     'name': 'Le Pain Quotidien',
#     'postal_code': 'WC2E 8RF',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 689572062,
#    'lat': 51.4065835,
#    'lon': -0.0304787,
#    'tags': {'amenity': 'restaurant', 'name': 'Pizza Express'},
#    'type': 'node'},
#   {'id': 690275859,
#    'lat': 51.5121948,
#    'lon': -0.0753621,
#    'tags': {'addr:housename': 'St Clare House',
#     'addr:housenumber': '30-33',
#     'addr:postcode': 'EC3N 1DD',
#     'addr:street': 'Minories',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Japanese Canteen'},
#    'type': 'node'},
#   {'id': 690718528,
#    'lat': 51.50634,
#    'lon': -0.145489,
#    'tags': {'amenity': 'restaurant', 'name': 'Tiger Green'},
#    'type': 'node'},
#   {'id': 690719946,
#    'lat': 51.506698,
#    'lon': -0.145675,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '17',
#     'addr:street': 'Half Moon Street',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '5',
#     'fhrs:id': '410917',
#     'fhrs:local_authority_id': '00107/0017/0/000',
#     'fhrs:rating': '5',
#     'fhrs:rating_date': '2010-09-22',
#     'fhrs:structural': '5',
#     'name': 'Kiku',
#     'postal_code': 'W1J 7BE',
#     'source:addr': 'FSA Food Hygiene Ratings Database',
#     'source:postcode': 'FSA Food Hygiene Ratings Database'},
#    'type': 'node'},
#   {'id': 691084120,
#    'lat': 51.5167874,
#    'lon': -0.1410871,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '26-28',
#     'addr:postcode': 'W1W 8QT',
#     'addr:street': 'Great Portland Street',
#     'amenity': 'restaurant',
#     'contact:website': 'http://www.wahaca.co.uk/locations/great-portland-st/',
#     'cuisine': 'mexican',
#     'name': 'Wahaca',
#     'opening_hours': 'Mo-Fr 08:00-23:00; Sa 09:00-23:00; Su 09:00-22:30',
#     'outdoor_seating': 'yes',
#     'payment:american_express': 'yes',
#     'phone': '+44 203 002 8784',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 691084126,
#    'lat': 51.5170079,
#    'lon': -0.1415043,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Tinseltown',
#     'outdoor_seating': 'no',
#     'wheelchair': 'limited'},
#    'type': 'node'},
#   {'id': 691114559,
#    'lat': 51.5182097,
#    'lon': -0.141482,
#    'tags': {'addr:housenumber': '14',
#     'addr:street': 'Riding House Street',
#     'amenity': 'restaurant',
#     'cuisine': 'oriental_fusion',
#     'name': 'Fusion Food House'},
#    'type': 'node'},
#   {'id': 691635154,
#    'lat': 51.5109233,
#    'lon': -0.1276968,
#    'tags': {'addr:housenumber': '28-34',
#     'addr:street': "St Martin's Court",
#     'amenity': 'restaurant',
#     'fhrs:confidence_management': '5',
#     'fhrs:hygiene': '5',
#     'fhrs:id': '414450',
#     'fhrs:local_authority_id': '01779/0028/0/000',
#     'fhrs:rating': '5',
#     'fhrs:rating_date': '2012-05-30',
#     'fhrs:structural': '5',
#     'name': 'j sheekys',
#     'name:en': 'j sheekys',
#     'phone': '020 7240 2565',
#     'postal_code': 'WC2N 4AL',
#     'website': 'http://www.j-sheekey.co.uk/'},
#    'type': 'node'},
#   {'id': 691728906,
#    'lat': 51.517662,
#    'lon': -0.136886,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '21',
#     'addr:street': 'Berners Street',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:confidence_management': '10',
#     'fhrs:hygiene': '10',
#     'fhrs:id': '412332',
#     'fhrs:local_authority_id': '00765/0021/0/002',
#     'fhrs:rating': '2',
#     'fhrs:rating_date': '2013-06-26',
#     'fhrs:structural': '15',
#     'name': 'Latium',
#     'phone': '020 7323 9123',
#     'postal_code': 'W1T 3LP'},
#    'type': 'node'},
#   {'id': 691759506,
#    'lat': 51.5187648,
#    'lon': -0.1357193,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '33',
#     'addr:postcode': 'W1T 1RR',
#     'addr:street': 'Charlotte Street',
#     'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'Fino',
#     'opening_hours': 'Mo-Fr 12:00-14:30,18:00-22:30; Sa 18:00-22:30; Su off',
#     'phone': '+44 207 813 8010',
#     'postal_code': 'W1T 1RR',
#     'website': 'http://www.finorestaurant.com/'},
#    'type': 'node'},
#   {'id': 692043355,
#    'lat': 51.5373716,
#    'lon': -0.0613657,
#    'tags': {'amenity': 'restaurant', 'name': 'Off Broadway'},
#    'type': 'node'},
#   {'id': 692129363,
#    'lat': 51.5182383,
#    'lon': -0.1407167,
#    'tags': {'amenity': 'restaurant', 'name': 'The Riding House Cafe'},
#    'type': 'node'},
#   {'id': 692129403,
#    'lat': 51.5183891,
#    'lon': -0.1400631,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '52',
#     'addr:postcode': 'W1T 3PR',
#     'addr:street': 'Wells Street',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'internet_access': 'wlan',
#     'name': 'Homeslice',
#     'opening_hours': 'Mo-Sa 12:00-23:00; Su 12:00-22:00',
#     'phone': '+44 203 151 9273',
#     'website': 'http://www.homeslicepizza.co.uk/',
#     'wheelchair': 'yes'},
#    'type': 'node'},
#   {'id': 692162500,
#    'lat': 51.5127258,
#    'lon': -0.0852031,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'steak_house',
#     'name': 'Gaucho'},
#    'type': 'node'},
#   {'id': 692162524,
#    'lat': 51.5124628,
#    'lon': -0.0832116,
#    'tags': {'addr:housenumber': '30',
#     'amenity': 'restaurant',
#     'name': 'We Grill'},
#    'type': 'node'},
#   {'id': 692162534,
#    'lat': 51.5126585,
#    'lon': -0.0833025,
#    'tags': {'amenity': 'restaurant', 'name': 'La Tasca'},
#    'type': 'node'},
#   {'id': 692162550,
#    'lat': 51.5127356,
#    'lon': -0.0833287,
#    'tags': {'addr:housenumber': '13',
#     'amenity': 'restaurant',
#     'name': 'Osteria del Mercato'},
#    'type': 'node'},
#   {'id': 692190788,
#    'lat': 51.5137234,
#    'lon': -0.1299858,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '10',
#     'addr:postcode': 'W1D 4TF',
#     'addr:street': 'Old Compton Street',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Taro',
#     'opening_hours': 'Mo-Th 12:00-22:30; Fr 12:00-22:45; Sa 12:30-22:45; Su 12:30-21:30',
#     'phone': '0207 439 2275',
#     'phone_1': '02074392275',
#     'website': 'http://www.tarorestaurants.co.uk',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 692190863,
#    'lat': 51.5138235,
#    'lon': -0.1298355,
#    'tags': {'addr:city': 'London',
#     'addr:housenumber': '8',
#     'addr:street': 'Old Compton Street',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'fhrs:confidence_management': '10',
#     'fhrs:hygiene': '5',
#     'fhrs:id': '412510',
#     'fhrs:local_authority_id': '00859/0008/0/001',
#     'fhrs:rating': '3',
#     'fhrs:rating_date': '2012-01-06',
#     'fhrs:structural': '10',
#     'name': 'Piccolo Diavolo',
#     'payment:american_express': 'yes',
#     'postal_code': 'W1D 4TE',
#     'website': 'http://www.piccolodiavolo.co.uk/',
#     'wheelchair': 'limited'},
#    'type': 'node'},
#   {'id': 692296635,
#    'lat': 51.5107543,
#    'lon': -0.1282258,
#    'tags': {'addr:housenumber': '24',
#     'addr:street': 'Charing Cross Road',
#     'amenity': 'restaurant',
#     'cuisine': 'burger',
#     'name': 'Byron',
#     'wheelchair': 'no'},
#    'type': 'node'},
#   {'id': 693188885,
#    'lat': 51.509548,
#    'lon': -0.134945,
#    'tags': {'amenity': 'restaurant', 'name': 'Scotch Steakhouse'},
#    'type': 'node'},
#   {'id': 693189988,
#    'lat': 51.507968,
#    'lon': -0.131124,
#    'tags': {'amenity': 'restaurant', 'name': 'Mint Leaf'},
#    'type': 'node'},
#   {'id': 694159622,
#    'lat': 51.5117014,
#    'lon': -0.0757505,
#    'tags': {'amenity': 'restaurant', 'name': 'Missouri Angel'},
#    'type': 'node'},
#   {'id': 694475188,
#    'lat': 51.510634,
#    'lon': -0.077099,
#    'tags': {'amenity': 'restaurant', 'name': 'Keepers'},
#    'type': 'node'},
#   {'id': 694510208,
#    'lat': 51.5088796,
#    'lon': -0.0789428,
#    'tags': {'amenity': 'restaurant', 'name': 'Wagamama'},
#    'type': 'node'},
#   {'id': 694510269,
#    'lat': 51.5089063,
#    'lon': -0.0790823,
#    'tags': {'amenity': 'restaurant', 'name': 'GBK'},
#    'type': 'node'},
#   {'id': 694824542,
#    'lat': 51.509196,
#    'lon': -0.0789213,
#    'tags': {'amenity': 'restaurant',
#     'name': 'beyondboyle',
#     'website': 'http://www.beyondboyle.com'},
#    'type': 'node'},
#   {'id': 696546831,
#    'lat': 51.5231835,
#    'lon': -0.1365336,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Japanese Canteen',
#     'opening_hours': 'Mo-Su 11:30-22:00',
#     'toilets': 'yes',
#     'toilets:access': 'customers',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'},
#    'type': 'node'},
#   {'id': 696913693,
#    'lat': 51.51122,
#    'lon': -0.0776408,
#    'tags': {'addr:housenumber': '26A',
#     'addr:postcode': 'EC3N 2AR',
#     'addr:street': 'Savage Gardens',
#     'amenity': 'restaurant',
#     'cuisine': 'fish',
#     'name': 'Orpheus',
#     'phone': '02074811931'},
#    'type': 'node'},
#   {'id': 696927640,
#    'lat': 51.51072,
#    'lon': -0.080403,
#    'tags': {'amenity': 'restaurant', 'name': 'China Delight'},
#    'type': 'node'},
#   ...],
#  'generator': 'Overpass API',
#  'osm3s': {'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.',
#   'timestamp_osm_base': '2017-05-05T09:39:27Z'},
#  'version': 0.6}

# %% [markdown]
# Export JSON to a file (Write JSON)

# %%
labels = ['id', 'lat', 'lon', 'type', 'tags']
df = pd.DataFrame.from_records(restaurants, columns = labels)
df
# Out:
# Empty DataFrame
# Columns: [id, lat, lon, type, tags]
# Index: []
